# %%
import sys
import logging
from pathlib import Path

import pandas as pd
import matplotlib.pyplot as plt
import pyarrow as pa
import pyarrow.parquet as pq

# %%
PROJECT_ROOT = Path().resolve().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

# %%
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s | %(levelname)s | %(message)s",
)

logger = logging.getLogger(__name__)

# %%
from context import CRMPromoContext

from data.db import get_gp_connection

from data.loaders import (
    load_orders_with_geo,
    load_customers,
    load_segments,
)

from config.settings import DB_CONFIG

from config.promo_types import (
    PromoMechanicType,
)

from pipelines.crm_pipeline import (
    run_crm_pipeline,
)

from evaluation.plots import (
    plot_propensity_distribution,
    plot_uplift_distribution,
)

# %%
PROMO_CODE = "ВЕСНАЦВЕТЕТ"

PROMO_START = "2026-02-26"
PROMO_END = "2026-03-26"

LOAD_START = "2026-01-20"
LOAD_END = "2026-04-15"

PRE_PERIOD_DAYS = 30
POST_PERIOD_DAYS = 14

# %%
logger.info("=" * 60)
logger.info("LOAD DATA")
logger.info("=" * 60)

with get_gp_connection(**DB_CONFIG) as conn:

    # =====================================================
    # TREATMENT ORDERS
    # =====================================================

    logger.info("LOAD PROMO ORDERS")

    promo_orders = load_orders_with_geo(
        conn=conn,
        start_date=LOAD_START,
        end_date=LOAD_END,
        promo_code=PROMO_CODE,
        only_promo=True,
    )

    logger.info(
        f"PROMO ORDERS SHAPE: "
        f"{promo_orders.shape}"
    )
    # =====================================================
    # CONTROL ORDERS
    # =====================================================

    logger.info("LOAD CONTROL ORDERS")

    control_orders = load_orders_with_geo(
        conn=conn,
        start_date=LOAD_START,
        end_date=LOAD_END,
        promo_code=None,
        only_promo=False,
        sample_fraction=0.002,
        limit=50_000,
    )

    logger.info(
        f"CONTROL ORDERS SHAPE: "
        f"{control_orders.shape}"
    )
    # =====================================================
    # UNION ORDERS
    # =====================================================

    orders = pd.concat(
        [
            promo_orders,
            control_orders,
        ],
        ignore_index=True,
    )

    logger.info(
        f"TOTAL ORDERS SHAPE: "
        f"{orders.shape}"
    )

    # =====================================================
    # ACTIVE CUSTOMERS
    # =====================================================

    active_rks = (
        orders["customer_rk"]
        .astype(str)
        .unique()
    )

    logger.info(
        f"ACTIVE CUSTOMERS: "
        f"{len(active_rks)}"
    )

    # =====================================================
    # CUSTOMERS
    # =====================================================

    customers = load_customers(
        conn=conn,
        customer_rks=active_rks,
    )

    logger.info(
        f"CUSTOMERS SHAPE: "
        f"{customers.shape}"
    )

    # =====================================================
    # SEGMENTS
    # =====================================================

    segments = load_segments(
        conn=conn,
        cutoff_date=PROMO_START,
    )

    logger.info(
        f"SEGMENTS SHAPE: "
        f"{segments.shape}"
    )
# Out:
# 2026-05-18 10:12:02,719 | INFO | ============================================================
# 2026-05-18 10:12:02,720 | INFO | LOAD DATA
# 2026-05-18 10:12:02,720 | INFO | ============================================================
# 2026-05-18 10:12:02,721 | INFO | 🔌 Connecting to DB: greenplum-prod.dwh.ecom.tech:5433/gp_prd
# 2026-05-18 10:12:03,011 | INFO | LOAD PROMO ORDERS
# 2026-05-18 10:12:03,012 | INFO | ============================================================
# 2026-05-18 10:12:03,012 | INFO | LOADING ORDERS WITH GEO
# 2026-05-18 10:12:03,014 | INFO | ============================================================
# 2026-05-18 10:12:03,024 | INFO | Period: 2026-01-20 → 2026-04-15
# 2026-05-18 10:12:03,026 | INFO | Promo mode enabled: ВЕСНАЦВЕТЕТ
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/data/loaders.py:150: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql(
# 2026-05-18 10:12:04,341 | INFO | Chunk #1: 17,165 rows (total: 17,165)
# 2026-05-18 10:12:04,345 | INFO | ============================================================
# 2026-05-18 10:12:04,345 | INFO | TOTAL ORDERS LOADED: 17,165
# 2026-05-18 10:12:04,345 | INFO | ============================================================
# 2026-05-18 10:12:04,346 | INFO | PROMO ORDERS SHAPE: (17165, 7)
# 2026-05-18 10:12:04,346 | INFO | LOAD CONTROL ORDERS
# 2026-05-18 10:12:04,347 | INFO | ============================================================
# 2026-05-18 10:12:04,347 | INFO | LOADING ORDERS WITH GEO
# 2026-05-18 10:12:04,347 | INFO | ============================================================
# 2026-05-18 10:12:04,347 | INFO | Period: 2026-01-20 → 2026-04-15
# 2026-05-18 10:12:04,348 | INFO | Loading ALL orders (treated + control)
# 2026-05-18 10:12:04,348 | WARNING | DEBUG LIMIT ENABLED: 50,000
# 2026-05-18 10:12:04,348 | WARNING | SQL SAMPLE ENABLED: 0.20%
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/data/loaders.py:150: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql(
# 2026-05-18 10:12:05,642 | INFO | Chunk #1: 50,000 rows (total: 50,000)
# 2026-05-18 10:12:05,647 | INFO | ============================================================
# 2026-05-18 10:12:05,648 | INFO | TOTAL ORDERS LOADED: 50,000
# 2026-05-18 10:12:05,648 | INFO | ============================================================
# 2026-05-18 10:12:05,648 | INFO | CONTROL ORDERS SHAPE: (50000, 7)
# 2026-05-18 10:12:05,650 | INFO | TOTAL ORDERS SHAPE: (67165, 7)
# 2026-05-18 10:12:05,659 | INFO | ACTIVE CUSTOMERS: 65639
# 2026-05-18 10:12:05,660 | INFO | ============================================================
# 2026-05-18 10:12:05,660 | INFO | LOADING CUSTOMERS
# 2026-05-18 10:12:05,660 | INFO | ============================================================
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/data/loaders.py:242: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(
# 2026-05-18 10:15:01,449 | INFO | Loaded customers: 314,916
# 2026-05-18 10:15:01,472 | INFO | Unique customer_rk: 65,639
# 2026-05-18 10:15:01,477 | INFO | CUSTOMERS SHAPE: (314916, 2)
# 2026-05-18 10:15:01,478 | INFO | ============================================================
# 2026-05-18 10:15:01,479 | INFO | LOADING SEGMENTS
# 2026-05-18 10:15:01,479 | INFO | ============================================================
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/data/loaders.py:327: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(
# 2026-05-18 10:34:37,643 | INFO | Loaded rows: 21,872,880
# 2026-05-18 10:34:59,569 | INFO | Unique customers: 21,872,880
# 2026-05-18 10:34:59,572 | INFO | SEGMENTS SHAPE: (21872880, 5)
# 2026-05-18 10:34:59,583 | INFO | 🔌 Connection closed

# %%
# =========================================================
# BASIC CHECKS
# =========================================================

logger.info("=" * 60)
logger.info("DATA VALIDATION")
logger.info("=" * 60)

print("\nORDERS:")
print(orders.shape)

print("\nCUSTOMERS:")
print(customers.shape)

print("\nSEGMENTS:")
print(segments.shape)
# Out:
# 2026-05-18 10:57:02,653 | INFO | ============================================================
# 2026-05-18 10:57:02,656 | INFO | DATA VALIDATION
# 2026-05-18 10:57:02,656 | INFO | ============================================================
# ORDERS:
# (67165, 7)
#
# CUSTOMERS:
# (314916, 2)
#
# SEGMENTS:
# (21872880, 5)

# %%
# =========================================================
# PROMO SHARE
# =========================================================

orders["is_promo"] = (
    orders["promo_code"] == PROMO_CODE
).astype(int)

promo_share = orders["is_promo"].mean()

print("\nPROMO SHARE:")
print(round(promo_share, 4))
# Out:
# PROMO SHARE:
# 0.2557

# %%
# =========================================================
# CREATE CONTEXT
# =========================================================

ctx = CRMPromoContext(
    mechanic_type=PromoMechanicType.CRM,

    promo_name="Весна Цветет 2026",

    orders_df=orders,
    customers_df=customers,
    segments_df=segments,

    promo_code=PROMO_CODE,

    promo_start=PROMO_START,
    promo_end=PROMO_END,

    pre_period_days=PRE_PERIOD_DAYS,
    post_period_days=POST_PERIOD_DAYS,
)

# %%
# =========================================================
# RUN PIPELINE
# =========================================================

logger.info("=" * 60)
logger.info("RUN CRM PIPELINE")
logger.info("=" * 60)

result = run_crm_pipeline(
    ctx=ctx,
    debug_mode=False,
)
# Out:
# 2026-05-18 10:57:11,889 | INFO | ============================================================
# 2026-05-18 10:57:11,891 | INFO | RUN CRM PIPELINE
# 2026-05-18 10:57:11,891 | INFO | ============================================================
# 2026-05-18 10:57:11,893 | INFO | ============================================================
# 2026-05-18 10:57:11,895 | INFO | START CRM PIPELINE
# 2026-05-18 10:57:11,896 | INFO | ============================================================
# 2026-05-18 10:57:11,897 | INFO | STEP 1: BUILD DATASET
# 2026-05-18 10:57:11,898 | INFO | ============================================================
# 2026-05-18 10:57:11,899 | INFO | BUILD PROMO DATASET
# 2026-05-18 10:57:11,900 | INFO | ============================================================
# 2026-05-18 10:57:12,122 | INFO | Orders in window: 66,464
# 2026-05-18 10:57:12,130 | INFO | Unique customers: 64,948
# 2026-05-18 10:57:12,136 | INFO | Treated users: 15,844
# 2026-05-18 10:57:12,181 | INFO | Users active in pre-period: 37,232
# 2026-05-18 10:57:12,292 | INFO | Users after activity filter: 37,197
# 2026-05-18 10:57:12,293 | INFO | Treated share: 0.0048
# 2026-05-18 10:57:12,293 | INFO | Treated users: 177
# 2026-05-18 10:57:12,293 | INFO | Control users: 37,020
# 2026-05-18 10:57:12,297 | INFO | Base dataset shape: (37197, 5)
# 2026-05-18 10:57:12,449 | INFO | customer_id coverage: 98.48%
# 2026-05-18 10:58:58,700 | INFO | segment coverage: 84.30%
# 2026-05-18 10:59:00,167 | INFO | ============================================================
# 2026-05-18 10:59:00,167 | INFO | FINAL DATASET SHAPE: (37197, 15)
# 2026-05-18 10:59:00,168 | INFO | ============================================================
# 2026-05-18 10:59:00,203 | INFO | Dataset shape: (37197, 15)
# 2026-05-18 10:59:00,210 | INFO | Dataset memory usage: 8.39 MB
# 2026-05-18 10:59:00,211 | INFO | STEP 2: FEATURE ENGINEERING
# 2026-05-18 10:59:00,222 | INFO | 🔧 Applying feature engineering...
# 2026-05-18 10:59:00,243 | INFO |    - Clipped outliers in ['revenue_pre', 'revenue_sum', 'revenue_post']
| INFO | Fitting X-Learner Stage 2 (Imputation & CATE models)...
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# 2026-05-18 10:59:01,599 | INFO | 💰 Total Incremental Revenue: 939.29 ₽
# 2026-05-18 10:59:01,599 | INFO | 📊 Avg Incremental per Treated User: 5.43 ₽
# 2026-05-18 10:59:01,600 | INFO | Incremental Revenue: 939.29 ₽
# 2026-05-18 10:59:01,604 | INFO | STEP 8: BOOTSTRAP CI
# 2026-05-18 10:59:01,608 | INFO | 🔹 Fitting X-Learner...
# 2026-05-18 10:59:01,609 | INFO | Fitting X-Learner Stage 1 (Outcome models)...
# 2026-05-18 10:59:01,799 | INFO | Fitting X-Learner Stage 2 (Imputation & CATE models)...
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# 2026-05-18 10:59:02,241 | INFO | 💰 Total Incremental Revenue: 939.29 ₽
# 2026-05-18 10:59:02,241 | INFO | 📊 Avg Incremental per Treated User: 5.43 ₽
# 2026-05-18 10:59:02,370 | INFO | 🔹 Fitting X-Learner...
# 2026-05-18 10:59:02,370 | INFO | Fitting X-Learner Stage 1 (Outcome models)...
# 2026-05-18 10:59:02,655 | INFO | Fitting X-Learner Stage 2 (Imputation & CATE models)...
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# 2026-05-18 10:59:02,980 | INFO | 💰 Total Incremental Revenue: -501.10 ₽
# 2026-05-18 10:59:02,981 | INFO | 📊 Avg Incremental per Treated User: -2.80 ₽
# 2026-05-18 10:59:03,011 | INFO | 🔹 Fitting X-Learner...
# 2026-05-18 10:59:03,011 | INFO | Fitting X-Learner Stage 1 (Outcome models)...
# 2026-05-18 10:59:03,288 | INFO | Fitting X-Learner Stage 2 (Imputation & CATE models)...
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# 2026-05-18 10:59:03,615 | INFO | 💰 Total Incremental Revenue: 961.63 ₽
# 2026-05-18 10:59:03,615 | INFO | 📊 Avg Incremental per Treated User: 5.86 ₽
# 2026-05-18 10:59:03,623 | INFO | 🔹 Fitting X-Learner...
# 2026-05-18 10:59:03,624 | INFO | Fitting X-Learner Stage 1 (Outcome models)...
# 2026-05-18 10:59:03,862 | INFO | Fitting X-Learner Stage 2 (Imputation & CATE models)...
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# 2026-05-18 10:59:04,094 | INFO | 💰 Total Incremental Revenue: 8.67 ₽
# 2026-05-18 10:59:04,095 | INFO | 📊 Avg Incremental per Treated User: 0.05 ₽
# 2026-05-18 10:59:04,102 | INFO | 🔹 Fitting X-Learner...
# 2026-05-18 10:59:04,103 | INFO | Fitting X-Learner Stage 1 (Outcome models)...
# 2026-05-18 10:59:04,296 | INFO | Fitting X-Learner Stage 2 (Imputation & CATE models)...
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# 2026-05-18 10:59:04,513 | INFO | 💰 Total Incremental Revenue: -1,073.48 ₽
# 2026-05-18 10:59:04,514 | INFO | 📊 Avg Incremental per Treated User: -6.93 ₽
# 2026-05-18 10:59:04,521 | INFO | 🔹 Fitting X-Learner...
# 2026-05-18 10:59:04,521 | INFO | Fitting X-Learner Stage 1 (Outcome models)...
# 2026-05-18 10:59:04,712 | INFO | Fitting X-Learner Stage 2 (Imputation & CATE models)...
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# 2026-05-18 10:59:04,952 | INFO | 💰 Total Incremental Revenue: 746.91 ₽
# 2026-05-18 10:59:04,952 | INFO | 📊 Avg Incremental per Treated User: 4.34 ₽
# 2026-05-18 10:59:04,960 | INFO | 🔹 Fitting X-Learner...
# 2026-05-18 10:59:04,961 | INFO | Fitting X-Learner Stage 1 (Outcome models)...
# 2026-05-18 10:59:05,163 | INFO | Fitting X-Learner Stage 2 (Imputation & CATE models)...
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# 2026-05-18 10:59:05,391 | INFO | 💰 Total Incremental Revenue: -150.37 ₽
# 2026-05-18 10:59:05,391 | INFO | 📊 Avg Incremental per Treated User: -0.86 ₽
# 2026-05-18 10:59:05,399 | INFO | 🔹 Fitting X-Learner...
# 2026-05-18 10:59:05,399 | INFO | Fitting X-Learner Stage 1 (Outcome models)...
# 2026-05-18 10:59:05,569 | INFO | Fitting X-Learner Stage 2 (Imputation & CATE models)...
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# 2026-05-18 10:59:05,807 | INFO | 💰 Total Incremental Revenue: -583.31 ₽
# 2026-05-18 10:59:05,808 | INFO | 📊 Avg Incremental per Treated User: -3.33 ₽
# 2026-05-18 10:59:05,818 | INFO | 🔹 Fitting X-Learner...
# 2026-05-18 10:59:05,819 | INFO | Fitting X-Learner Stage 1 (Outcome models)...
# 2026-05-18 10:59:06,003 | INFO | Fitting X-Learner Stage 2 (Imputation & CATE models)...
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# 2026-05-18 10:59:06,238 | INFO | 💰 Total Incremental Revenue: 1,941.64 ₽
# 2026-05-18 10:59:06,239 | INFO | 📊 Avg Incremental per Treated User: 10.33 ₽
# 2026-05-18 10:59:06,246 | INFO | 🔹 Fitting X-Learner...
# 2026-05-18 10:59:06,247 | INFO | Fitting X-Learner Stage 1 (Outcome models)...
# 2026-05-18 10:59:06,412 | INFO | Fitting X-Learner Stage 2 (Imputation & CATE models)...
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# 2026-05-18 10:59:06,631 | INFO | 💰 Total Incremental Revenue: 1,826.08 ₽
# 2026-05-18 10:59:06,631 | INFO | 📊 Avg Incremental per Treated User: 10.32 ₽
# 2026-05-18 10:59:06,638 | INFO | 🔹 Fitting X-Learner...
# 2026-05-18 10:59:06,639 | INFO | Fitting X-Learner Stage 1 (Outcome models)...
# 2026-05-18 10:59:06,807 | INFO | Fitting X-Learner Stage 2 (Imputation & CATE models)...
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# 2026-05-18 10:59:07,022 | INFO | 💰 Total Incremental Revenue: 945.05 ₽
# 2026-05-18 10:59:07,023 | INFO | 📊 Avg Incremental per Treated User: 6.10 ₽
# 2026-05-18 10:59:07,030 | INFO | 🔹 Fitting X-Learner...
# 2026-05-18 10:59:07,030 | INFO | Fitting X-Learner Stage 1 (Outcome models)...
# 2026-05-18 10:59:07,189 | INFO | Fitting X-Learner Stage 2 (Imputation & CATE models)...
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# 2026-05-18 10:59:07,448 | INFO | 💰 Total Incremental Revenue: -139.02 ₽
# 2026-05-18 10:59:07,448 | INFO | 📊 Avg Incremental per Treated User: -0.80 ₽
# 2026-05-18 10:59:07,456 | INFO | 🔹 Fitting X-Learner...
# 2026-05-18 10:59:07,456 | INFO | Fitting X-Learner Stage 1 (Outcome models)...
# 2026-05-18 10:59:07,623 | INFO | Fitting X-Learner Stage 2 (Imputation & CATE models)...
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# 2026-05-18 10:59
...
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# 2026-05-18 10:59:48,427 | INFO | 💰 Total Incremental Revenue: -642.81 ₽
# 2026-05-18 10:59:48,428 | INFO | 📊 Avg Incremental per Treated User: -3.76 ₽
# 2026-05-18 10:59:48,432 | INFO | 95% CI: [-724.5590370902905, 3130.606566741814]
# 2026-05-18 10:59:48,446 | INFO | STEP 9: DOUBLE ML VALIDATION
# 2026-05-18 10:59:48,447 | INFO | Fitting DoubleML (Cross-fitting)...
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# 2026-05-18 10:59:50,332 | INFO | 🎯 DML ATE: 4.77 ₽ | SE: 5.85
# 2026-05-18 10:59:50,333 | INFO | DML ATE: 4.767562618415865
# 2026-05-18 10:59:50,333 | INFO | ============================================================
# 2026-05-18 10:59:50,333 | INFO | CRM PIPELINE FINISHED
# 2026-05-18 10:59:50,334 | INFO | ============================================================

# %%
# =========================================================
# MAIN METRICS
# =========================================================

print("\n" + "=" * 60)
print("MAIN RESULTS")
print("=" * 60)

print("\nIncremental Revenue:")
print(round(result["incremental_revenue"], 2))

print("\n95% Confidence Interval:")
print(result["ci_95"])

print("\nATE DML:")
print(result["ate_dml"])
# Out:
# ============================================================
# MAIN RESULTS
# ============================================================
#
# Incremental Revenue:
# 939.29
#
# 95% Confidence Interval:
# (-724.5590370902905, 3130.606566741814)
#
# ATE DML:
# 4.767562618415865

# %%
# =========================================================
# STATISTICAL SIGNIFICANCE
# =========================================================

ci_lower, ci_upper = result["ci_95"]

print("\nStatistical Significance:")

if (
    ci_lower is not None
    and ci_upper is not None
):

    if ci_lower > 0:

        print(
            "Effect is statistically positive."
        )

    elif ci_upper < 0:

        print(
            "Effect is statistically negative."
        )

    else:

        print(
            "Effect is not statistically significant."
        )

else:

    print(
        "Confidence interval unavailable."
    )
# Out:
# Statistical Significance:
# Effect is not statistically significant.

# %%
# =========================================================
# TREATMENT SUMMARY
# =========================================================

print("\n" + "=" * 60)
print("TREATMENT SUMMARY")
print("=" * 60)

display(
    pd.DataFrame(
        [result["treatment_summary"]]
    )
)
# Out:
# ============================================================
# TREATMENT SUMMARY
# ============================================================
#    n_total  n_treated  n_control  treated_share
# 0    37197        177      37020       0.004758

# %%
# =========================================================
# OVERLAP RESULT
# =========================================================

print("\n" + "=" * 60)
print("OVERLAP DIAGNOSTICS")
print("=" * 60)

display(
    pd.DataFrame(
        [result["overlap_result"]]
    )
)
# Out:
# ============================================================
# OVERLAP DIAGNOSTICS
# ============================================================
#    overlap_exists                            overlap_range  overlap_share  \
# 0            True  (0.566630001045593, 0.9688824684573233)       0.120736
#
#                              treated_range  \
# 0  (0.566630001045593, 0.9688824684573233)
#
#                                  control_range
# 0  (8.898416066391221e-06, 0.9985110265647392)

# %%
# =========================================================
# BALANCE TABLE
# =========================================================

print("\n" + "=" * 60)
print("BALANCE TABLE")
print("=" * 60)

display(
    result["balance_table"]
)
# Out:
# ============================================================
# BALANCE TABLE
# ============================================================
#              control_mean  treated_mean   abs_diff
# revenue_pre   1267.782681   1297.196532  29.413850
# revenue_sum   1267.782681   1297.196532  29.413850
# orders_cnt       1.004725      1.011561   0.006836
# avg_check     1282.629320   1313.760116  31.130796

# %%
# =========================================================
# FEATURE IMPORTANCE
# =========================================================

print("\n" + "=" * 60)
print("PROPENSITY FEATURE IMPORTANCE")
print("=" * 60)

feature_importance = (
    result["feature_importance"]
    .sort_values(
        "importance",
        ascending=False,
    )
)

display(
    feature_importance.head(20)
)
# Out:
# ============================================================
# PROPENSITY FEATURE IMPORTANCE
# ============================================================
#                         feature  importance
# 0                   revenue_pre         537
# 4                     avg_check         497
# 6               log_revenue_pre         405
# 37             home_city_Москва         104
# 63    home_city_Санкт-Петербург          80
# 117          gender_Женский пол          65
# 107           age_Возраст_25_29          61
# 87   customer_segment_Базовый 1          54
# 109           age_Возраст_35_39          49
# 108           age_Возраст_30_34          46
# 32         home_city_Красноярск          44
# 88   customer_segment_Базовый 2          43
# 47        home_city_Новосибирск          43
# 59     home_city_Ростов-на-Дону          42
# 25             home_city_Казань          39
# 43    home_city_Нижний Новгород          37
# 112           age_Возраст_50_54          36
# 5                discount_share          36
# 105              age_Возраст_23          34
# 51               home_city_Омск          32

# %%
# =========================================================
# UPLIFT SUMMARY
# =========================================================

print("\n" + "=" * 60)
print("UPLIFT SUMMARY")
print("=" * 60)

display(
    pd.DataFrame(
        [result["uplift_summary"]]
    )
)
# Out:
# ============================================================
# UPLIFT SUMMARY
# ============================================================
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 11
#       7 print("=" * 60)
#       8
#       9 display(
#      10     pd.DataFrame(
# ---> 11         [result["uplift_summary"]]
#      12     )
#      13 )
#
# KeyError: 'uplift_summary'

# %%
# =========================================================
# PLOTS
# =========================================================

logger.info("PLOT PROPENSITY DISTRIBUTION")

plot_propensity_distribution(
    result["df_predictions"]
)

plt.show()

logger.info("PLOT UPLIFT DISTRIBUTION")

plot_uplift_distribution(
    result["df_predictions"]
)

plt.show()
# Out:
# 2026-05-18 11:16:56,001 | INFO | PLOT PROPENSITY DISTRIBUTION
# 2026-05-18 11:16:56,373 | INFO | PLOT UPLIFT DISTRIBUTION

# %%
# =========================================================
# TOP UPLIFT USERS
# =========================================================

print("\n" + "=" * 60)
print("TOP UPLIFT USERS")
print("=" * 60)

top_users = (
    result["df_predictions"]
    .sort_values(
        "uplift",
        ascending=False,
    )
    .head(20)
)

display(top_users)
# Out:
# ============================================================
# TOP UPLIFT USERS
# ============================================================
#                             customer_rk  revenue_pre  revenue_post    y  T  \
# 17040  9ed83099f8a78119163deb47d9b69351       2723.0           0.0  0.0  0
# 19594  448100ed4b9d2fcb1cba7ae93183bb9c       2736.0           0.0  0.0  0
# 2383   fb124849261045e702556c92de7c3e25       2983.0           0.0  0.0  0
# 7073   3354df37b9404e3b2c417a29329b9a69       2933.0           0.0  0.0  0
# 36666  02f3ea735e7a6b92111332375afc2de9       1007.0           0.0  0.0  0
# 10039  b39de4796f0a3efeb12c3dda90a8a1be       2915.0           0.0  0.0  0
# 507    1579aadb1d794849ecf7ad9939a66fde        652.0           0.0  0.0  0
# 3328   1d33780fd33ad8b6326abc912dc80867        817.0           0.0  0.0  1
# 507                        0                   1                   0
# 3328                       0                   0                   1
# 29072                      0                   0                   1
# 24339                      0                   1                   0
# 20803                      0                   1                   0
# 33360                      0                   1                   0
# 23890                      0                   1                   0
# 10523                      0                   1                   0
# 10271                      0                   1                   0
# 27249                      0                   1                   0
# 11652                      0                   1                   0
# 29420                      0                   1                   0
# 7723                       0                   1                   0
# 34943                      0                   1                   0
#
#        propensity_score     uplift  tau_0_pred  tau_1_pred
# 17040          0.673932  18.566438   24.929672    5.414645
# 19594          0.688815  18.383042   24.241767    5.414645
# 2383           0.485224  16.664703   28.599918    5.414645
# 7073           0.404271  14.769115   28.553777    5.414645
# 36666          0.543920  14.074448   21.335733    5.414645
# 10039          0.399326  13.412593   25.443290    5.414645
# 507            0.728332  12.038454   14.509138    5.414645
# 3328           0.928608  11.874311   12.370935    5.414645
# 29072          0.832753  11.261987   12.436347    5.414645
# 24339          0.862068  11.213783   12.141651    5.414645
# 20803          0.842284  10.886578   11.911186    5.414645
# 33360          0.472864  10.733751   16.663341    5.414645
# 23890          0.759842  10.673046   12.335031    5.414645
# 10523          0.222826  10.580922   28.599918    5.414645
# 10271          0.730741  10.519354   12.400307    5.414645
# 27249          0.766476  10.493666   12.041107    5.414645
# 11652          0.721495  10.454763   12.400307    5.414645
# 29420          0.721495  10.454763   12.400307    5.414645
# 7723           0.707754  10.359882   12.401867    5.414645
# 34943          0.708644  10.319728   12.336436    5.414645
#
# [20 rows x 127 columns]

# %%
# =========================================================
# SAVE ARTIFACT
# =========================================================

logger.info("=" * 60)
logger.info("SAVE PARQUET")
logger.info("=" * 60)

artifacts_dir = (
    PROJECT_ROOT / "artifacts"
)

artifacts_dir.mkdir(
    exist_ok=True
)

output_path = (
    artifacts_dir / "vesna_uplift.parquet"
)

table = pa.Table.from_pandas(
    result["df_predictions"]
)

pq.write_table(
    table,
    output_path,
)

logger.info(
    f"Saved parquet to: {output_path}"
)

print("\nPARQUET SAVED:")
print(output_path)
# Out:
# 2026-05-18 11:17:05,794 | INFO | ============================================================
# 2026-05-18 11:17:05,796 | INFO | SAVE PARQUET
# 2026-05-18 11:17:05,797 | INFO | ============================================================
# 2026-05-18 11:17:05,918 | INFO | Saved parquet to: /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/artifacts/vesna_uplift.parquet
# PARQUET SAVED:
# /Users/hq-fvfkjjjz1wfv/Documents/tasks/Инкремент/offline_uplift/artifacts/vesna_uplift.parquet

# %%
# =========================================================
# FINAL SUMMARY
# =========================================================

print("\n" + "=" * 60)
print("FINAL SUMMARY")
print("=" * 60)

print(
    f"""
Promo: {PROMO_CODE}

Incremental Revenue:
{round(result["incremental_revenue"], 2)} ₽

ATE DML:
{result["ate_dml"]}

Dataset Shape:
{result["dataset_shape"]}

Feature Count:
{result["feature_count"]}

Trimmed Rows:
{result["trimmed_rows"]}
"""
)
# Out:
# ============================================================
# FINAL SUMMARY
# ============================================================
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 26
#      22 Feature Count:
#      23 {result["feature_count"]}
#      24
#      25 Trimmed Rows:
# ---> 26 {result["trimmed_rows"]}
#      27 """
#      28 )
#
# KeyError: 'trimmed_rows'
